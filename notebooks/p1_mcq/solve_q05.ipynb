# %%
import pandas as pd
import duckdb
con = duckdb.connect()

# %%
query = """
    SELECT (COUNT(promo_id) * 100.0) / COUNT(*) as promo_percentage
    FROM '../../data/transaction/order_items.csv'
"""

# %%
promo_percentage = con.execute(query).df()
promo_percentage
# Out:
#    promo_percentage
# 0         38.663493
